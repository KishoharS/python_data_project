# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# loading data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(7)
# Out:
#                   job_title_short                                   job_title  \
# 182549               Data Analyst                            SAP Data Analyst
# 475692      Senior Data Scientist              (Senior) Data Science Engineer
# 541631  Machine Learning Engineer           Sr. AV/VTC Engineer (100% Onsite)
# 360463           Business Analyst  Senior IT Business Analyst (Tampa) IV 4.21
# 252540             Data Scientist                  Data & Analytics Recruiter
# 132525               Data Analyst                         Data Analyst Intern
# 379951              Data Engineer                            BI Data Engineer
#
#          job_location                job_via job_schedule_type  \
# 182549     Irving, TX              via BeBee         Full-time
# 475692        Austria              via BeBee         Full-time
# 541631    Coppell, TX       via ZipRecruiter         Full-time
# 360463      Tampa, FL  via My Stateline Jobs         Full-time
# ...

# %%
df.sample(7, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
#
#                    job_location                 job_via job_schedule_type  \
# 502901              St Paul, MN               via BeBee         Full-time
# 406337               London, UK            via LinkedIn         Full-time
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_original = df
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 6425290000

# %%
df_altered = df_original

#calculating the median value

median_salary = df_altered['salary_year_avg'].median()

median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']  # Original data remains unchanged
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

df_original = df
df_altered = df_original.copy()

# %%
print("Original DataFrame ID:", id(df_original))
print("Altered DataFrame ID:", id(df_altered))
print("Are both the dataframes have the same ID?", id(df_original) == id(df_altered))
# Out:
# Original DataFrame ID: 6411919952
# Altered DataFrame ID: 6411920224
# Are both the dataframes have the same ID? False

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
